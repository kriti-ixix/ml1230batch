# %%
import pandas as pd

# %%
df = pd.read_csv('country_vaccinations.csv')

# %%
df.head()
# Out:
#    country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Albania      ALB  2021-01-10                 0.0                0.0
# 1  Albania      ALB  2021-01-11                 NaN                NaN
# 2  Albania      ALB  2021-01-12               128.0              128.0
# 3  Albania      ALB  2021-01-13               188.0              188.0
# 4  Albania      ALB  2021-01-14               266.0              266.0
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN                64.0
# 2                      NaN                     NaN                64.0
# 3                      NaN                    60.0                63.0
# 4                      NaN                    78.0                66.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %%
df.head(10)
# Out:
#    country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Albania      ALB  2021-01-10                 0.0                0.0
# 1  Albania      ALB  2021-01-11                 NaN                NaN
# 2  Albania      ALB  2021-01-12               128.0              128.0
# 3  Albania      ALB  2021-01-13               188.0              188.0
# 4  Albania      ALB  2021-01-14               266.0              266.0
# 5  Albania      ALB  2021-01-15               308.0              308.0
# 6  Albania      ALB  2021-01-16               369.0              369.0
# 7  Albania      ALB  2021-01-17               405.0              405.0
# 8  Albania      ALB  2021-01-18               447.0              447.0
# 9  Albania      ALB  2021-01-19               483.0              483.0
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# ...

# %%
df.shape[0]
# Out:
# 6186

# %%
df.shape
# Out:
# (6186, 15)

# %%
netflix = pd.read_csv('netflix_titles.csv')

# %%
netflix.shape
# Out:
# (7787, 12)

# %%
netflix.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020          2020  TV-MA  4 Seasons
# 1  December 23, 2016          2016  TV-MA     93 min
# 2  December 20, 2018          2011      R     78 min
# 3  November 16, 2017          2009  PG-13     80 min
# ...

# %%
netflix[netflix['release_year']==2020]
# Out:
#      show_id     type                                title           director  \
# 0         s1  TV Show                                   3%                NaN
# 24       s25  TV Show  ​SAINT SEIYA: Knights of the Zodiac                NaN
# 26       s27  TV Show                             (Un)Well                NaN
# 27       s28    Movie                               #Alive             Cho Il
# 29       s30  TV Show                             #blackAF                NaN
# ...      ...      ...                                  ...                ...
# 7725   s7726  TV Show                      You Cannot Hide                NaN
# 7734   s7735    Movie                      You've Got This  Salvador Espinosa
# 7738   s7739  TV Show                      Young Wallander                NaN
# 7741   s7742    Movie            Your Name Engraved Herein      Liu Kuang-hui
# 7744   s7745    Movie          Yours Sincerely, Kanan Gill       Neville Shah
#
# ...

# %%
netflix[netflix['release_year']==2020]['title']
# Out:
# 0                                        3%
# 24      ​SAINT SEIYA: Knights of the Zodiac
# 26                                 (Un)Well
# 27                                   #Alive
# 29                                 #blackAF
#                        ...
# 7725                        You Cannot Hide
# 7734                        You've Got This
# 7738                        Young Wallander
# 7741              Your Name Engraved Herein
# 7744            Yours Sincerely, Kanan Gill
# Name: title, Length: 868, dtype: object

# %%
newshows = netflix[netflix['release_year']==2020][['title', 'director']]
newshows
# Out:
#                                     title           director
# 0                                      3%                NaN
# 24    ​SAINT SEIYA: Knights of the Zodiac                NaN
# 26                               (Un)Well                NaN
# 27                                 #Alive             Cho Il
# 29                               #blackAF                NaN
# ...                                   ...                ...
# 7725                      You Cannot Hide                NaN
# 7734                      You've Got This  Salvador Espinosa
# 7738                      Young Wallander                NaN
# 7741            Your Name Engraved Herein      Liu Kuang-hui
# 7744          Yours Sincerely, Kanan Gill       Neville Shah
#
# [868 rows x 2 columns]

# %%
newshows.to_csv('new_shows.csv')
