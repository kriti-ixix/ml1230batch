# %%
import pandas as pd
import numpy as np

# %%
netflix = pd.read_csv('netflix_titles.csv')

# %%
netflix.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020          2020  TV-MA  4 Seasons
# 1  December 23, 2016          2016  TV-MA     93 min
# 2  December 20, 2018          2011      R     78 min
# 3  November 16, 2017          2009  PG-13     80 min
# ...

# %%
netflix.sample(10)
# Out:
#      show_id     type                      title  \
# 3245   s3246    Movie          Jupiter Ascending
# 4878   s4879    Movie                Planetarium
# 1030   s1031    Movie                       Bolt
# 6270   s6271    Movie               The Darkness
# 1282   s1283  TV Show  Charlie's Colorforms City
# 3931   s3932  TV Show                   Marcella
# 3984   s3985    Movie                     Master
# 4423   s4424    Movie   National Parks Adventure
# 1794   s1795  TV Show           Documentary Now!
# 7185   s7186    Movie                     Tramps
#
#                              director  \
# 3245  Lana Wachowski, Lilly Wachowski
# 4878                Rebecca Zlotowski
# 1030     Byron Howard, Chris Williams
# 6270                      Greg McLean
# 1282                              NaN
# 3931                              NaN
# 3984                       Ui-seok Jo
# 4423                Greg MacGillivray
# 1794                              NaN
# ...

# %%
netflix.shape
# Out:
# (7787, 12)

# %%
ipl = pd.read_csv('IPL Matches.csv')

# %%
ipl.head()
# Out:
#        id        city        date player_of_match  \
# 0  335982   Bangalore  2008-04-18     BB McCullum
# 1  335983  Chandigarh  2008-04-19      MEK Hussey
# 2  335984       Delhi  2008-04-19     MF Maharoof
# 3  335985      Mumbai  2008-04-20      MV Boucher
# 4  335986     Kolkata  2008-04-20       DJ Hussey
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
# 3                            Wankhede Stadium              0
# 4                                Eden Gardens              0
#
#                          team1                        team2  \
# 0  Royal Challengers Bangalore        Kolkata Knight Riders
# 1              Kings XI Punjab          Chennai Super Kings
# 2             Delhi Daredevils             Rajasthan Royals
# ...

# %%
ipl.columns
# Out:
# Index(['id', 'city', 'date', 'player_of_match', 'venue', 'neutral_venue',
#        'team1', 'team2', 'toss_winner', 'toss_decision', 'winner', 'result',
#        'result_margin', 'eliminator', 'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
netflix.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
ipl.shape
# Out:
# (816, 17)

# %%
ipl['result_margin']>100
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 811    False
# 812    False
# 813    False
# 814    False
# 815    False
# Name: result_margin, Length: 816, dtype: bool

# %%
importantmatches = ipl[ipl['result_margin']>100]

# %%
importantmatches
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 55    336038      Mumbai  2008-05-30       SR Watson
# 236   501260  Dharamsala  2011-05-17    AC Gilchrist
# 351   598027   Bangalore  2013-04-23        CH Gayle
# 497   829785   Bangalore  2015-05-06        CH Gayle
# 560   980987   Bangalore  2016-05-14  AB de Villiers
# 620  1082635       Delhi  2017-05-06     LMP Simmons
# 676  1136601     Kolkata  2018-05-09    Ishan Kishan
# 706  1175366   Hyderabad  2019-03-31     JM Bairstow
#
#                                             venue  neutral_venue  \
# 0                           M Chinnaswamy Stadium              0
# 55                               Wankhede Stadium              0
# 236  Himachal Pradesh Cricket Association Stadium              0
# 351                         M Chinnaswamy Stadium              0
# 497                         M Chinnaswamy Stadium              0
# ...

# %%
importantmatches.shape
# Out:
# (9, 17)

# %%
importantmatches.columns
# Out:
# Index(['id', 'city', 'date', 'player_of_match', 'venue', 'neutral_venue',
#        'team1', 'team2', 'toss_winner', 'toss_decision', 'winner', 'result',
#        'result_margin', 'eliminator', 'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
importantmatches.set_index(pd.RangeIndex(0,9), inplace=True)
importantmatches
# Out:
#         id        city        date player_of_match  \
# 0   335982   Bangalore  2008-04-18     BB McCullum
# 1   336038      Mumbai  2008-05-30       SR Watson
# 2   501260  Dharamsala  2011-05-17    AC Gilchrist
# 3   598027   Bangalore  2013-04-23        CH Gayle
# 4   829785   Bangalore  2015-05-06        CH Gayle
# 5   980987   Bangalore  2016-05-14  AB de Villiers
# 6  1082635       Delhi  2017-05-06     LMP Simmons
# 7  1136601     Kolkata  2018-05-09    Ishan Kishan
# 8  1175366   Hyderabad  2019-03-31     JM Bairstow
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1                              Wankhede Stadium              0
# 2  Himachal Pradesh Cricket Association Stadium              0
# 3                         M Chinnaswamy Stadium              0
# 4                         M Chinnaswamy Stadium              0
# 5                         M Chinnaswamy Stadium              0
# ...

# %%
final = importantmatches[['id','date','player_of_match','team1','team2']]

# %%
final
# Out:
#         id        date player_of_match                        team1  \
# 0   335982  2008-04-18     BB McCullum  Royal Challengers Bangalore
# 1   336038  2008-05-30       SR Watson             Delhi Daredevils
# 2   501260  2011-05-17    AC Gilchrist              Kings XI Punjab
# 3   598027  2013-04-23        CH Gayle  Royal Challengers Bangalore
# 4   829785  2015-05-06        CH Gayle  Royal Challengers Bangalore
# 5   980987  2016-05-14  AB de Villiers  Royal Challengers Bangalore
# 6  1082635  2017-05-06     LMP Simmons             Delhi Daredevils
# 7  1136601  2018-05-09    Ishan Kishan        Kolkata Knight Riders
# 8  1175366  2019-03-31     JM Bairstow          Sunrisers Hyderabad
#
#                          team2
# 0        Kolkata Knight Riders
# 1             Rajasthan Royals
# 2  Royal Challengers Bangalore
# 3                Pune Warriors
# 4              Kings XI Punjab
# 5                Gujarat Lions
# 6               Mumbai Indians
# ...

# %%
final.shape
# Out:
# (9, 5)

# %%
final.to_csv('Important Matches.csv')

# %%
netflix.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020          2020  TV-MA  4 Seasons
# 1  December 23, 2016          2016  TV-MA     93 min
# 2  December 20, 2018          2011      R     78 min
# 3  November 16, 2017          2009  PG-13     80 min
# ...

# %%
netflix[(netflix['release_year']==2020) & (netflix['country']=='India')]
# Out:
#      show_id   type                                       title  \
# 244     s245  Movie                           A truthful Mother
# 362     s363  Movie                                    AK vs AK
# 368     s369  Movie                     Ala Vaikunthapurramuloo
# 510     s511  Movie                                 Andhakaaram
# 605     s606  Movie                                  Asura Guru
# ...      ...    ...                                         ...
# 7429   s7430  Movie  Vir Das: Outside In - The Lockdown Special
# 7547   s7548  Movie                          What Are the Odds?
# 7665   s7666  Movie                          World Famous Lover
# 7701   s7702  Movie                                  Yeh Ballet
# 7744   s7745  Movie                 Yours Sincerely, Kanan Gill
#
#                        director  \
# 244   Ravishankar Venkateswaran
# 362        Vikramaditya Motwane
# 368          Trivikram Srinivas
# 510                V Vignarajan
# ...
